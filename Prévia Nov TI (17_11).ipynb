# %% [markdown]
# ## Análise de Dados LEGAL - VIA - Modelo Desindexado

# %%
#Carga das bibliotecas utilizadas no estudo

import pandas as pd

#biblioteca para gráficos mais amigáveis
import seaborn as sns

#carrega módulo decision tree
from sklearn import tree

#Carrega métricas de avaliação de modelos
#Para modelos de regressão utilizamos R-quadrado, MAPE e MAE
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_absolute_error
#Para modelos de classificação utilizamos Acurácia, curva ROC / AUC
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc

#carrega módulo para tratar variáveis categóricas. trabalhando com modelos de árvore podemos usar o Label Encoder
from sklearn import preprocessing

#ANOVA - teste de independência entre variável categórica e contínua
import statsmodels.api as sm
from statsmodels.formula.api import ols

#Biblioteca para exibição gráfica do resultado da árvore de decisão treinada
import graphviz

#força o pandas a mostrar todas as colunas do dataframe
pd.set_option('display.max_columns', None)

#força o pandas a mostrar todas as linhas do dataframe
#pd.set_option("max_rows", None)

# %%
#Carga da base de Dados
dados = pd.read_excel("C:/Users/2104998693/Desktop/Novo Histórico 20_10.xlsx")

dados
# Out:
#        ID_PROCESSO   CADASTRO MES_CADASTRO AREA_DO_DIREITO  \
# 0             7562 2010-10-25   2010-10-01     TRABALHISTA
# 1             7630 2011-05-02   2011-05-01     TRABALHISTA
# 2             9229 2010-02-04   2010-02-01     TRABALHISTA
# 3             9366 2015-12-11   2015-12-01     TRABALHISTA
# 4            10121 2009-10-26   2009-10-01     TRABALHISTA
# ...            ...        ...          ...             ...
# 27424       953071 2021-08-23   2021-08-01     TRABALHISTA
# 27425       953830 2021-08-25   2021-08-01     TRABALHISTA
# 27426       953928 2021-08-25   2021-08-01     TRABALHISTA
# 27427       955355 2021-09-01   2021-09-01     TRABALHISTA
# 27428       956186 2021-09-06   2021-09-01     TRABALHISTA
#
#                SUB_AREA_DO_DIREITO  VALOR_DA_CAUSA  \
# 0      PREVENTIVO AUTO DE INFRAÇÃO            0.00
# 1      PREVENTIVO AUTO DE INFRAÇÃO            0.00
# 2      PREVENTIVO AUTO DE INFRAÇÃO            0.00
# 3             CONTENCIOSO COLETIVO            0.00
# 4           CONTENCIOSO INDIVIDUAL        30000.00
# ...                            ...             ...
# 27424       CONTENCIOSO INDIVIDUAL       100430.53
# 27425       CONTENCIOSO INDIVIDUAL        25698.18
# 27426       CONTENCIOSO INDIVIDUAL         1884.56
# 27427       CONTENCIOSO INDIVIDUAL       103601.94
# 27428       CONTENCIOSO INDIVIDUAL       103601.94
#
#                         ESCRITORIO_RESPONSAVEL PARTE_CONTRARIA_CPF  \
# 0      HASSAN E KOHATSU SOCIEDADE DE ADVOGADOS                 N/I
# 1      HASSAN E KOHATSU SOCIEDADE DE ADVOGADOS  37.115.367/0035-00
# 2             ADVOGADO INTERNO VV (ANTIGA CBD)                  NI
# 3      HASSAN E KOHATSU SOCIEDADE DE ADVOGADOS      042.422.287-67
# 4         DÉCIO FREIRE ADVOGADOS (TRABALHISTA)      585.654.181-20
# ...                                        ...                 ...
# 27424  AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS      402.356.288-24
# 27425  AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS      133.001.668-88
# 27426             DA COSTA FERNANDES ADVOGADOS      923.801.156-72
# 27427  AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS      513.768.898-38
# 27428  AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS      391.302.708-47
#
#                                     PARTE_CONTRARIA_NOME  \
# 0      MINISTERIO DO TRABALHO E EMPREGO - GLOBEX GPA ...
# 1                       MINISTERIO DO TRABALHO E EMPREGO
# 2                       MINISTERIO DO TRABALHO E EMPREGO
# 3      MINISTÉRIO PÚBLICO DO TRABALHO - 03/07/2015 - ...
# 4                              HUMBERTO CALDAS DE ARAÚJO
# ...                                                  ...
# 27424                      CICERO ELIAS DE ALMEIDA SOUZA
# 27425                               GILSON JOSE DA SILVA
# 27426                 LUCIANA APARECIDA DOS SANTOS MOTTI
# 27427                              FELIPE ALVES DA SILVA
# 27428                            JHONATAN ALMEIDA BORGES
#
#                 PROCESSO_ESTEIRA ESTADO                      COMARCA  \
# 0      ESTRATÉGICO (TRABALHISTA)     RJ               RIO DE JANEIRO
# 1      ESTRATÉGICO (TRABALHISTA)     MT                       MATUPÁ
# 2      ESTRATÉGICO (TRABALHISTA)     SP                       OSASCO
# 3      ESTRATÉGICO (TRABALHISTA)     SP                      CAJAMAR
# 4            MASSA (TRABALHISTA)     GO                      GOIÂNIA
# ...                          ...    ...                          ...
# 27424        MASSA (TRABALHISTA)     SP  SÃO PAULO - PENHA DE FRANÇA
# 27425        MASSA (TRABALHISTA)     SP                  CARAPICUÍBA
# 27426        MASSA (TRABALHISTA)     MG                     CONTAGEM
# 27427        MASSA (TRABALHISTA)     SP                    SÃO PAULO
# 27428        MASSA (TRABALHISTA)     SP                    SÃO PAULO
#
#       CLASSIFICACAO            NATUREZA_OPERACIONAL        DATA_ADMISSAO  \
# 0               MTE  SINDICATO / MINISTERIO PUBLICO  2010-10-11 00:00:00
# 1               MTE  SINDICATO / MINISTERIO PUBLICO                  NaN
# 2           PRÓPRIO                             NaN                  NaN
# 3               MPT  SINDICATO / MINISTERIO PUBLICO  2015-07-03 00:00:00
# 4           PRÓPRIO                             NaN  2007-06-01 00:00:00
# ...             ...                             ...                  ...
# 27424       PRÓPRIO                     OPERACIONAL  2019-01-07 00:00:00
# 27425       PRÓPRIO                        VENDEDOR  2021-02-08 00:00:00
# 27426       PRÓPRIO                     OPERACIONAL  2020-11-16 00:00:00
# 27427      TERCEIRO               TERCEIRO SOLVENTE  2019-10-10 00:00:00
# 27428      TERCEIRO               TERCEIRO SOLVENTE  2019-08-10 00:00:00
#
#          MES_DATA_ADMISSAO        DATA_DISPENSA    MES_DATA_DISPENSA  \
# 0      2010-10-01 00:00:00  2010-10-11 00:00:00  2010-10-01 00:00:00
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3      2015-07-01 00:00:00  2016-08-31 00:00:00  2016-08-01 00:00:00
# 4      2007-06-01 00:00:00  2008-09-01 00:00:00  2008-09-01 00:00:00
# ...                    ...                  ...                  ...
# 27424  2019-01-01 00:00:00  2020-03-06 00:00:00  2020-03-01 00:00:00
# 27425  2021-02-01 00:00:00  2021-04-06 00:00:00  2021-04-01 00:00:00
# 27426  2020-11-01 00:00:00  2021-03-11 00:00:00  2021-03-01 00:00:00
# 27427  2019-10-01 00:00:00  2021-02-14 00:00:00  2021-02-01 00:00:00
# 27428  2019-08-01 00:00:00  2021-01-16 00:00:00  2021-01-01 00:00:00
#
#               DISTRIBUICAO DISTRIBUICAO (ajustada)  \
# 0      2010-10-11 00:00:00              2010-10-01
# 1      2011-05-02 00:00:00              2011-05-01
# 2                      NaN                     NaT
# 3      2015-07-03 00:00:00              2015-07-01
# 4      2009-10-22 00:00:00              2009-10-01
# ...                    ...                     ...
# 27424  2021-08-17 00:00:00              2021-08-01
# 27425  2021-08-18 00:00:00              2021-08-01
# 27426  2021-08-23 00:00:00              2021-08-01
# 27427  2021-08-26 00:00:00              2021-08-01
# 27428  2021-08-30 00:00:00              2021-08-01
#
#       PARTE_CONTRARIA_CARGO_GRUPO          FASE FILIAL BAND  \
# 0                             N/D      EXECUÇÃO   0650  NaN
# 1                 SINDICATO / MPT           NaN   0650  NaN
# 2                             N/D           NaN   0650  NaN
# 3                 SINDICATO / MPT  CONHECIMENTO   1102  NaN
# 4                        VENDEDOR      EXECUÇÃO    650  NaN
# ...                           ...           ...    ...  ...
# 27424                    AUXILIAR  RECURSAL TRT   1290   CB
# 27425                    VENDEDOR  CONHECIMENTO   1456   CB
# 27426                    INSPETOR  CONHECIMENTO   1760  NaN
# 27427                    MONTADOR  RECURSAL TRT   1500  NaN
# 27428                    MONTADOR  RECURSAL TRT   1500  NaN
#
#                     NOME_DA_LOJA TIPO_BAND  ENCERRADOS MOTIVO_ENCERRAMENTO  \
# 0                            NaN       NaN           1           ARQUIVADO
# 1                            NaN       NaN           1           ARQUIVADO
# 2                            NaN       NaN           1           ARQUIVADO
# 3                            NaN       NaN           1           ARQUIVADO
# 4                            NaN       NaN           1           ARQUIVADO
# ...                          ...       ...         ...                 ...
# 27424        JD. IGUATEMI 2 - SP      LOJA           1                 NaN
# 27425           CARAPICUÍBA - SP      LOJA           1                 NaN
# 27426              1760-Contagem        CD           1                 NaN
# 27427  1500-S. Bernardo do Campo        CD           1                 NaN
# 27428  1500-S. Bernardo do Campo        CD           1                 NaN
#
#         MES_FECH MATRICULA  ACORDO  CONDENACAO  GARANTIA  PENHORA  IMPOSTO  \
# 0     2020-07-01       NaN     NaN         NaN       NaN      NaN      NaN
# 1     2020-03-01       NaN     NaN         NaN       NaN      NaN      NaN
# 2     2020-02-01       NaN     NaN         NaN       NaN      NaN      NaN
# 3     2021-01-01       NaN     NaN         NaN       NaN      NaN      NaN
# 4     2019-10-01       GPA     NaN         NaN  45118.46      NaN      NaN
# ...          ...       ...     ...         ...       ...      ...      ...
# 27424 2021-09-01       NaN     NaN         NaN       NaN      NaN      NaN
# 27425 2021-09-01       NaN     NaN         NaN       NaN      NaN      NaN
# 27426 2021-09-01       NaN  2200.0         NaN       NaN      NaN      NaN
# 27427 2021-09-01       NaN     NaN         NaN       NaN      NaN      NaN
# 27428 2021-09-01       NaN     NaN         NaN       NaN      NaN      NaN
#
#        OUTROS_PAGAMENTOS  TOTAL_PAGAMENTOS MOTIVO_ENC_AGRP CARGO AJUSTADO  \
# 0                    NaN               NaN        SEM ONUS         OUTROS
# 1                    NaN               NaN        SEM ONUS         OUTROS
# 2                    NaN               NaN        SEM ONUS         OUTROS
# 3                    NaN               NaN        SEM ONUS         OUTROS
# 4                    NaN          45118.46      CONDENACAO       VENDEDOR
# ...                  ...               ...             ...            ...
# 27424                NaN               NaN        SEM ONUS       AUXILIAR
# 27425                NaN               NaN        SEM ONUS       VENDEDOR
# 27426                NaN           2200.00          ACORDO         OUTROS
# 27427                NaN               NaN        SEM ONUS       MONTADOR
# 27428                NaN               NaN        SEM ONUS       MONTADOR
#
#        Tempo de Empresa Cluster Aging Tempo de Empresa  MESES_AGING_ENCERR  \
# 0                   0.0                      Até 1 ano                 119
# 1                   NaN                       Sem info                 108
# 2                   NaN                       Sem info                 122
# 3                  13.0                     1 - 2 anos                  62
# 4                  15.0                     1 - 2 anos                 122
# ...                 ...                            ...                 ...
# 27424              14.0                     1 - 2 anos                   1
# 27425               2.0                      Até 1 ano                   1
# 27426               4.0                      Até 1 ano                   1
# 27427              16.0                     1 - 2 anos                   0
# 27428              17.0                     1 - 2 anos                   0
#
#       Cluster Aging Safra de Reclamação TERCEIRO PRINCIPAL        ET  \
# 0           +7 ANOS                2010                NaN  Sem info
# 1           +7 ANOS            Sem info                NaN  Sem info
# 2           +7 ANOS            Sem info                NaN  Sem info
# 3        5 - 6 ANOS                2015                NaN  Sem info
# 4           +7 ANOS                2007                NaN  Sem info
# ...             ...                 ...                ...       ...
# 27424     ATÉ 1 ANO                2019                NaN  Sem info
# 27425     ATÉ 1 ANO                1986                NaN  Sem info
# 27426     ATÉ 1 ANO                2021                NaN  Sem info
# 27427     ATÉ 1 ANO                1992                NaN  Sem info
# 27428     ATÉ 1 ANO                1990                NaN  Sem info
#
#       Distribuição Data ULT_PGTO  Desindexador  Pagamento Desindexado  OUTLIER
# 0       2010-10-01    2020-07-01      3.472248               0.000000  Outlier
# 1       2011-05-01    2020-03-01      3.096638               0.000000  Outlier
# 2       2010-02-01    2020-02-01      3.594138               0.000000  Outlier
# 3       2015-07-01    2021-01-01      2.022005               0.000000  Outlier
# 4       2009-10-01    2019-10-01      3.594138           12553.345374    Hábil
# ...            ...           ...           ...                    ...      ...
# 27424   2021-08-01    2021-09-01      1.020100               0.000000  Outlier
# 27425   2021-08-01    2021-09-01      1.020100               0.000000  Outlier
# 27426   2021-08-01    2021-09-01      1.020100            2156.651309    Hábil
# 27427   2021-08-01    2021-09-01      1.020100               0.000000  Outlier
# 27428   2021-08-01    2021-09-01      1.020100               0.000000  Outlier
#
# [27429 rows x 51 columns]

# %%
estoque = pd.read_excel("C:/Users/2104998693/Desktop/FECHAMENTO_TRAB_20211122_4.xlsx")

estoque
# Out:
#          LINHA  ID PROCESSO         PASTA Área do Direito  \
# 0      linha00        11190  TRA.59077GPA     TRABALHISTA
# 1      linha00        12219  TRA.78824GPA     TRABALHISTA
# 2      linha00        16856  TRA.39538GPA     TRABALHISTA
# 3      linha00        16858  TRA.39664GPA     TRABALHISTA
# 4      linha00        16872  TRA.40136GPA     TRABALHISTA
# ...        ...          ...           ...             ...
# 32724  linha03       974658           NaN     TRABALHISTA
# 32725  linha03       974659           NaN     TRABALHISTA
# 32726  linha04       859329           NaN     TRABALHISTA
# 32727  linha04       877619           NaN     TRABALHISTA
# 32728  linha04       892236           NaN     TRABALHISTA
#
#           Sub-área do Direito Grupo (M-1)  \
# 0      CONTENCIOSO INDIVIDUAL         NaN
# 1      CONTENCIOSO INDIVIDUAL         NaN
# 2      CONTENCIOSO INDIVIDUAL         NaN
# 3      CONTENCIOSO INDIVIDUAL         NaN
# 4      CONTENCIOSO INDIVIDUAL         NaN
# ...                       ...         ...
# 32724  CONTENCIOSO INDIVIDUAL         NaN
# 32725  CONTENCIOSO INDIVIDUAL         NaN
# 32726    CONTENCIOSO COLETIVO         NaN
# 32727    CONTENCIOSO COLETIVO         NaN
# 32728    CONTENCIOSO COLETIVO         NaN
#
#                                 Empresa (M-1) Grupo (Fechamento)  \
# 0                           VIA VAREJO ONLINE                NaN
# 1                 GLOBEX UTILIDADES S/A (GPA)                NaN
# 2                 GLOBEX UTILIDADES S/A (GPA)                NaN
# 3                 GLOBEX UTILIDADES S/A (GPA)                NaN
# 4                 GLOBEX UTILIDADES S/A (GPA)                NaN
# ...                                       ...                ...
# 32724                                     NaN               VVAR
# 32725                                     NaN               VVAR
# 32726  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)                NaN
# 32727  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)                NaN
# 32728  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)                NaN
#
#                                   Empresa (M)      STATUS (M-1)  \
# 0                           VIA VAREJO ONLINE             ATIVO
# 1                 GLOBEX UTILIDADES S/A (GPA)  BAIXA PROVISORIA
# 2                 GLOBEX UTILIDADES S/A (GPA)         REATIVADO
# 3                 GLOBEX UTILIDADES S/A (GPA)  BAIXA PROVISORIA
# 4                 GLOBEX UTILIDADES S/A (GPA)  BAIXA PROVISORIA
# ...                                       ...               ...
# 32724  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)               NaN
# 32725  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)               NaN
# 32726  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)         REATIVADO
# 32727  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)         REATIVADO
# 32728  NOVA CASA BAHIA S/A (ATUAL VIA VAREJO)         REATIVADO
#
#              STATUS (M)                F12  Centro de Custo (M-1)  \
# 0                 ATIVO              ATIVO           2.106501e+09
# 1      BAIXA PROVISORIA   BAIXA PROVISORIA           2.106503e+09
# 2             REATIVADO          REATIVADO           2.106503e+09
# 3      BAIXA PROVISORIA   BAIXA PROVISORIA           2.106503e+09
# 4      BAIXA PROVISORIA   BAIXA PROVISORIA           2.106503e+09
# ...                 ...                ...                    ...
# 32724             ATIVO                NaN                    NaN
# 32725             ATIVO                NaN                    NaN
# 32726         ENCERRADO          ENCERRADO           2.110450e+09
# 32727         ENCERRADO          ENCERRADO           2.114453e+09
# 32728         ENCERRADO          ENCERRADO           2.115480e+09
#
#       Centro de Custo (M)    Cadastro  Reabertura Objeto Assunto/Cargo (M-1)  \
# 0              2106501056  19/06/2012         NaN                   AUXILIAR
# 1              2106503025  17/04/2015  11/06/2018                   AJUDANTE
# 2              2106503025  26/10/2009         NaN                   ANALISTA
# 3              2106503025  26/10/2009         NaN                ELETRICISTA
# 4              2106503025  26/10/2009         NaN                        NaN
# ...                   ...         ...         ...                        ...
# 32724          2114860003  19/11/2021         NaN                        NaN
# 32725          2112770003  19/11/2021         NaN                        NaN
# 32726          2110450003  16/06/2020         NaN            SINDICATO / MPT
# 32727          2114453055  25/09/2020         NaN            SINDICATO / MPT
# 32728          2115480003  25/11/2020         NaN                   VENDEDOR
#
#        Sub Objeto Assunto/Cargo (M-1) Objeto Assunto/Cargo (M)  \
# 0         AUXILIAR DE SERVICOS GERAIS                 AUXILIAR
# 1                            AJUDANTE                 AJUDANTE
# 2                ANALISTA DE NEGÓCIOS                 ANALISTA
# 3                         ELETRICISTA              ELETRICISTA
# 4                                 NaN                      NaN
# ...                               ...                      ...
# 32724                             NaN                 VENDEDOR
# 32725                             NaN                 VENDEDOR
# 32726  MINISTÉRIO PÚBLICO DO TRABALHO          SINDICATO / MPT
# 32727  MINISTÉRIO PÚBLICO DO TRABALHO          SINDICATO / MPT
# 32728                        VENDEDOR                 VENDEDOR
#
#          Sub Objeto Assunto/Cargo (M)  Órgão ofensor (Fluxo) (M-1)  \
# 0         AUXILIAR DE SERVICOS GERAIS                          NaN
# 1                            AJUDANTE                          NaN
# 2                ANALISTA DE NEGÓCIOS                          NaN
# 3                         ELETRICISTA                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 32724                VENDEDOR INTERNO                          NaN
# 32725                VENDEDOR INTERNO                          NaN
# 32726  MINISTÉRIO PÚBLICO DO TRABALHO                          NaN
# 32727  MINISTÉRIO PÚBLICO DO TRABALHO                          NaN
# 32728                        VENDEDOR                          NaN
#
#        Órgão ofensor (Fluxo) (M)      Natureza Operacional (M-1)  \
# 0                            NaN               TERCEIRO SOLVENTE
# 1                            NaN             TERCEIRO INSOLVENTE
# 2                            NaN                     OPERACIONAL
# 3                            NaN             TERCEIRO INSOLVENTE
# 4                            NaN             TERCEIRO INSOLVENTE
# ...                          ...                             ...
# 32724                        NaN                             NaN
# 32725                        NaN                             NaN
# 32726                        NaN  SINDICATO / MINISTERIO PUBLICO
# 32727                        NaN  SINDICATO / MINISTERIO PUBLICO
# 32728                        NaN                        VENDEDOR
#
#              Natureza Operacional (M)  Média de Pagamento    % Risco  \
# 0                   TERCEIRO SOLVENTE                0.00   0.000000
# 1                 TERCEIRO INSOLVENTE           118538.24   0.000000
# 2                         OPERACIONAL            96634.42  44.832193
# 3                 TERCEIRO INSOLVENTE                0.00   0.000000
# 4                   TERCEIRO SOLVENTE             8543.12   0.000000
# ...                               ...                 ...        ...
# 32724                        VENDEDOR                0.00   0.000000
# 32725                        VENDEDOR                0.00   0.000000
# 32726  SINDICATO / MINISTERIO PUBLICO                0.00   0.000000
# 32727  SINDICATO / MINISTERIO PUBLICO                0.00   0.000000
# 32728                        VENDEDOR                0.00   0.000000
#
#       Distribuição                Nº Processo  \
# 0       28/05/2012  0000843-82.2012.5.02.0221
# 1       17/11/2014  0011556-93.2014.5.01.0021
# 2       21/01/2009  0005200-07.2009.5.01.0038
# 3       14/02/2007  0018600-90.2007.5.01.0060
# 4       22/06/2007  0079400-74.2007.5.01.0031
# ...            ...                        ...
# 32724   18/11/2021  0011365-27.2021.5.15.0049
# 32725   17/11/2021  0011303-11.2021.5.15.0041
# 32726   29/05/2020       001888.2020.15.000/8
# 32727   23/09/2020       002843.2020.04.000/5
# 32728   03/11/2020  0000702-74.2020.5.09.0678
#
#                                     Escritorio  Vlr Causa  % Sócio (M-1)  \
# 0      AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS   35000.00           78.0
# 1      AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS   30000.00          100.0
# 2      AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS   20000.00          100.0
# 3      AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS       0.00          100.0
# 4      AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS       0.00          100.0
# ...                                        ...        ...            ...
# 32724  AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS   95357.95            0.0
# 32725  AUTUORI, BURMANN SOCIEDADE DE ADVOGADOS  100013.43            0.0
# 32726  HASSAN E KOHATSU SOCIEDADE DE ADVOGADOS       0.00            0.0
# 32727  HASSAN E KOHATSU SOCIEDADE DE ADVOGADOS       0.00            0.0
# 32728  HASSAN E KOHATSU SOCIEDADE DE ADVOGADOS    2000.00            0.0
#
#        % Empresa (M-1)  % Sócio (M)  % Empresa (M)  Provisão (M-1)  \
# 0                 22.0         78.0           22.0            0.00
# 1                  0.0        100.0            0.0            0.00
# 2                  0.0        100.0            0.0       159856.56
# 3                  0.0        100.0            0.0            0.00
# 4                  0.0        100.0            0.0            0.00
# ...                ...          ...            ...             ...
# 32724              0.0          0.0          100.0            0.00
# 32725              0.0          0.0          100.0            0.00
# 32726            100.0          0.0            0.0            0.00
# 32727            100.0          0.0            0.0            0.00
# 32728            100.0          0.0            0.0         8683.62
#
#        Correção  (M-1)  Provisão Total (M-1) Classificação Mov. (M)  \
# 0                 0.00                  0.00       SEM MOVIMENTAÇÃO
# 1                 0.00                  0.00              ENCERRADO
# 2               703.37             160559.93       OUTRAS REVERSÕES
# 3                 0.00                  0.00              ENCERRADO
# 4                 0.00                  0.00              ENCERRADO
# ...                ...                   ...                    ...
# 32724             0.00                  0.00       SEM MOVIMENTAÇÃO
# 32725             0.00                  0.00       SEM MOVIMENTAÇÃO
# 32726             0.00                  0.00              ENCERRADO
# 32727             0.00                  0.00              ENCERRADO
# 32728            38.21               8721.82              ENCERRADO
#
#        Provisão Mov. (M)  Correção Mov. (M)  Provisão Mov. Total (M)  \
# 0                   0.00           0.000000                     0.00
# 1                   0.00           0.000000                     0.00
# 2             -116533.23        1094.548195               -115438.68
# 3                   0.00           0.000000                     0.00
# 4                   0.00           0.000000                     0.00
# ...                  ...                ...                      ...
# 32724               0.00           0.000000                     0.00
# 32725               0.00           0.000000                     0.00
# 32726               0.00           0.000000                     0.00
# 32727               0.00           0.000000                     0.00
# 32728           -8683.62         -38.210000                 -8721.82
#
#        Provisão Total (M)  Correção (M-1)  Correção (M)  \
# 0                    0.00            0.00      0.000000
# 1                    0.00            0.00      0.000000
# 2                43323.33          703.37   1094.548195
# 3                    0.00            0.00      0.000000
# 4                    0.00            0.00      0.000000
# ...                   ...             ...           ...
# 32724                0.00            0.00      0.000000
# 32725                0.00            0.00      0.000000
# 32726                0.00            0.00      0.000000
# 32727                0.00            0.00      0.000000
# 32728                0.00            0.00      0.000000
#
#        Provisão Total Passivo (M) Demitido por Reestruturação  \
# 0                        0.000000                         NÃO
# 1                        0.000000                         NÃO
# 2                    45121.248195                         NÃO
# 3                        0.000000                         NÃO
# 4                        0.000000                         NÃO
# ...                           ...                         ...
# 32724                    0.000000                         NÃO
# 32725                    0.000000                         NÃO
# 32726                    0.000000                         NaN
# 32727                    0.000000                         NÃO
# 32728                    0.000000                         NÃO
#
#       Indicação Processo Estratégico  Filial (M)  Novos  Encerrados  Estoque  \
# 0                                NaN         NaN      1           1        1
# 1                                NaN         NaN      1           1        1
# 2                                NaN         NaN      1           1        1
# 3                                NaN         NaN      1           1        1
# 4                                NaN         NaN      1           1        1
# ...                              ...         ...    ...         ...      ...
# 32724                         DEFESA         NaN      1           1        1
# 32725                         DEFESA         NaN      1           1        1
# 32726                            NaN         NaN      1           1        1
# 32727                            NaN         NaN      1           1        1
# 32728                         ACORDO         NaN      1           1        1
#
#       CADASTRO_AJUSTADO MES_CADASTRO DISTRIBUICAO MES_DISTRIBUICAO  \
# 0            2012-06-19   2012-06-01   2012-05-28       2012-05-01
# 1            2015-04-17   2015-04-01   2014-11-17       2014-11-01
# 2            2009-10-26   2009-10-01   2009-01-21       2009-01-01
# 3            2009-10-26   2009-10-01   2007-02-14       2007-02-01
# 4            2009-10-26   2009-10-01   2007-06-22       2007-06-01
# ...                 ...          ...          ...              ...
# 32724        2021-11-19   2021-11-01   2021-11-18       2021-11-01
# 32725        2021-11-19   2021-11-01   2021-11-17       2021-11-01
# 32726        2020-06-16   2020-06-01   2020-05-29       2020-05-01
# 32727        2020-09-25   2020-09-01   2020-09-23       2020-09-01
# 32728        2020-11-25   2020-11-01   2020-11-03       2020-11-01
#
#                       FASE  DE_PARA_FASE ESTADO  \
# 0      EXECUÇÃO DEFINITIVA      EXECUÇÃO     SP
# 1      EXECUÇÃO DEFINITIVA      EXECUÇÃO     RJ
# 2      EXECUÇÃO DEFINITIVA      EXECUÇÃO     RJ
# 3      EXECUÇÃO DEFINITIVA      EXECUÇÃO     RJ
# 4      EXECUÇÃO DEFINITIVA      EXECUÇÃO     RJ
# ...                    ...           ...    ...
# 32724         CONHECIMENTO  CONHECIMENTO     SP
# 32725         CONHECIMENTO  CONHECIMENTO     SP
# 32726         CONHECIMENTO  CONHECIMENTO     SP
# 32727         CONHECIMENTO  CONHECIMENTO     RS
# 32728  EXECUÇÃO DEFINITIVA      EXECUÇÃO     PR
#
#                                       TERCEIRO_PRINCIPAL  \
# 0                    SERVSUL TC SERV LIMP JD E PORT LTDA
# 1                     BRAGIL SEGURANÇA E VIGILÂNCIA LDTA
# 2                                                    NaN
# 3      METAZINCO INDUSTRIA COMERCIO E SERVICOS - EIRELI
# 4                    SOLIDEZ SEGURANCA E VIGILANCIA LTDA
# ...                                                  ...
# 32724                                                NaN
# 32725                                                NaN
# 32726                                                NaN
# 32727                                                NaN
# 32728                                                NaN
#
#                                            NOVO_TERCEIRO PARTE_CONTRARIA_CPF  \
# 0                    SERVSUL TC SERV LIMP JD E PORT LTDA      061.025.323-92
# 1                     BRAGIL SEGURANÇA E VIGILÂNCIA LDTA      009.232.607-22
# 2                                                    NaN      861.113.967-49
# 3      METAZINCO INDUSTRIA COMERCIO E SERVICOS - EIRELI       893.515.257-91
# 4                    SOLIDEZ SEGURANCA E VIGILANCIA LTDA                  NI
# ...                                                  ...                 ...
# 32724                                                NaN      479.912.458-70
# 32725                                                NaN      202.569.868-27
# 32726                                                NaN  26.989.715/0001-02
# 32727                                                NaN  26.989.715/0001-02
# 32728                                                NaN      018.633.919-40
#
#              DATA_ADMISSAO   MES_FECH        DATA_DISPENSA  \
# 0      2011-07-01 00:00:00 2021-11-22  2012-01-31 00:00:00
# 1      2007-09-13 00:00:00 2021-11-22  2014-06-29 00:00:00
# 2      2003-06-03 00:00:00 2021-11-22  2008-08-08 00:00:00
# 3      2003-10-21 00:00:00 2021-11-22  2006-11-02 00:00:00
# 4      2002-11-03 00:00:00 2021-11-22  2006-12-27 00:00:00
# ...                    ...        ...                  ...
# 32724  2018-08-08 00:00:00 2021-11-22  2021-10-05 00:00:00
# 32725  2018-10-09 00:00:00 2021-11-22  2021-10-06 00:00:00
# 32726                  NaN 2021-11-22                  NaN
# 32727                  NaN 2021-11-22                  NaN
# 32728  2006-12-04 00:00:00 2021-11-22  2012-04-16 00:00:00
#
#          MES_DATA_ADMISSAO    MES_DATA_DISPENSA  TEMPO_EMPRESA_MESES  \
# 0      2011-07-01 00:00:00  2012-01-01 00:00:00                  6.0
# 1      2007-09-01 00:00:00  2014-06-01 00:00:00                 81.0
# 2      2003-06-01 00:00:00  2008-08-01 00:00:00                 62.0
# 3      2003-10-01 00:00:00  2006-11-01 00:00:00                 37.0
# 4      2002-11-01 00:00:00  2006-12-01 00:00:00                 49.0
# ...                    ...                  ...                  ...
# 32724  2018-08-01 00:00:00  2021-10-01 00:00:00                 38.0
# 32725  2018-10-01 00:00:00  2021-10-01 00:00:00                 36.0
# 32726                  NaN                  NaN                  NaN
# 32727                  NaN                  NaN                  NaN
# 32728  2006-12-01 00:00:00  2012-04-01 00:00:00                 64.0
#
#        MESES_AGING_ESTOQ FX_MES_AGING_ESTOQ FX_ANO_AGING_ESTOQ  \
# 0                    113          +24 meses            +7 anos
# 1                     79          +24 meses         6 - 7 anos
# 2                    145          +24 meses            +7 anos
# 3                    145          +24 meses            +7 anos
# 4                    145          +24 meses            +7 anos
# ...                  ...                ...                ...
# 32724                  0        até 6 meses          até 1 ano
# 32725                  0        até 6 meses          até 1 ano
# 32726                 17      13 - 18 meses         1 - 2 anos
# 32727                 14      13 - 18 meses         1 - 2 anos
# 32728                 12       7 - 12 meses         1 - 2 anos
#
#       Cluster Aging Tempo de Empresa Cluster Aging Safra de Reclamação  \
# 0                          Até 1 ano       +7 ANOS                2011
# 1                        6 - 10 anos    6 - 7 ANOS                2009
# 2                         5 - 6 anos       +7 ANOS                2003
# 3                         3 - 4 anos       +7 ANOS                2003
# 4                         4 - 5 anos       +7 ANOS                2002
# ...                              ...           ...                 ...
# 32724                     3 - 4 anos     ATÉ 1 ANO                2018
# 32725                     2 - 3 anos     ATÉ 1 ANO                2018
# 32726                       Sem info    1 - 2 ANOS            Sem info
# 32727                       Sem info    1 - 2 ANOS            Sem info
# 32728                     5 - 6 anos     ATÉ 1 ANO                2007
#
#               ET
# 0         Outros
# 1      Segurança
# 2       Sem info
# 3         Outros
# 4      Segurança
# ...          ...
# 32724   Sem info
# 32725   Sem info
# 32726   Sem info
# 32727   Sem info
# 32728   Sem info
#
# [32729 rows x 74 columns]

# %% [markdown]
# ## Análise Exploratória de Dados
#
# Análise das variáveis disponíveis, sua distribuição. Testes das primeiras hipóteses e avaliação do efeito de possíveis variáveis explicativas na resposta (alvo do estudo) - análise bivariada.

# %%
#Avaliar de maneira simples a distribuição de todas as variáveis numéricas
dados.describe()
# Out:
#          ID_PROCESSO  VALOR_DA_CAUSA  ENCERRADOS        ACORDO    CONDENACAO  \
# count   27429.000000    2.736700e+04     27429.0  8.293000e+03  8.466000e+03
# mean   582460.486784    6.921896e+04         1.0  4.174918e+04  1.749914e+05
# std    270878.097195    7.252237e+05         0.0  9.059008e+04  2.935192e+05
# min      7562.000000    0.000000e+00         1.0  1.000000e+02  5.010000e+00
# 25%    250223.000000    5.000000e+02         1.0  1.800000e+04  2.454617e+04
# 50%    657302.000000    5.000000e+03         1.0  3.300000e+04  7.665154e+04
# 75%    825159.000000    6.332000e+04         1.0  4.518500e+04  1.976532e+05
# max    956186.000000    1.161836e+08         1.0  6.500000e+06  6.081233e+06
#
#            GARANTIA       PENHORA        IMPOSTO  OUTROS_PAGAMENTOS  \
# count  1.123100e+04  9.320000e+02    4111.000000       6.580000e+02
# mean   4.980187e+04  1.273883e+05   16820.409616       5.946563e+04
# std    1.450597e+05  2.053804e+05   41985.722864       1.273735e+05
# min   -5.414600e+02  0.000000e+00       0.000000       2.426000e+01
# 25%    9.676795e+03  9.967978e+03    1972.220000       2.906182e+03
# 50%    1.789750e+04  5.314718e+04    5135.820000       1.091270e+04
# 75%    3.797115e+04  1.592558e+05   14074.975000       5.337581e+04
# max    6.252668e+06  1.867489e+06  949096.380000       1.396960e+06
#
#        TOTAL_PAGAMENTOS  Tempo de Empresa  MESES_AGING_ENCERR  Desindexador  \
# count      2.197400e+04      25943.000000        27429.000000  27429.000000
# mean       1.189602e+05         63.575839           35.780087      1.526630
# std        2.509501e+05         56.491530           28.387701      0.798752
# min       -4.717600e+02      -1439.000000            0.000000      1.010000
# 25%        1.964645e+04         22.000000            8.000000      1.082857
# 50%        4.200000e+04         49.000000           34.000000      1.347849
# 75%        1.100000e+05         92.000000           56.000000      1.742270
# max        1.275267e+07       1418.000000          145.000000     17.000000
#
#        Pagamento Desindexado
# count           2.742900e+04
# mean            5.866298e+04
# std             1.257766e+05
# min            -3.243286e+01
# 25%             2.935574e+03
# 50%             2.284492e+04
# 75%             5.553720e+04
# max             3.704893e+06

# %%
#Definição dos clusters
cluster_sp = ['SP']
cluster_rj = ['RJ']
cluster_alto_valor = ['MG', 'DF']
cluster_medio_valor = ['SC','PR','RS','BA','GO','MS'] 

#Criação de nova variável, agrupando os estados por perfil de faixa de valores
dados['cluster_valor'] = dados.ESTADO.apply(lambda x: 'ALTO VALOR' if x in cluster_alto_valor 
                                            else 'MEDIO VALOR' if x in cluster_medio_valor 
                                            else 'SP' if x in cluster_sp
                                            else 'RJ' if x in cluster_rj
                                            else 'OUTROS')

dados.groupby(dados['cluster_valor']).count()
# Out:
#                ID_PROCESSO  CADASTRO  MES_CADASTRO  AREA_DO_DIREITO  \
# cluster_valor
# ALTO VALOR            3815      3815          3815             3815
# MEDIO VALOR           3806      3806          3806             3806
# OUTROS                1623      1623          1623             1617
# RJ                    6824      6824          6824             6824
# SP                   11361     11361         11361            11361
#
#                SUB_AREA_DO_DIREITO  VALOR_DA_CAUSA  ESCRITORIO_RESPONSAVEL  \
# cluster_valor
# ALTO VALOR                    3815            3815                    3815
# MEDIO VALOR                   3806            3803                    3806
# OUTROS                        1617            1572                    1617
# RJ                            6824            6819                    6824
# SP                           11361           11358                   11361
#
#                PARTE_CONTRARIA_CPF  PARTE_CONTRARIA_NOME  PROCESSO_ESTEIRA  \
# cluster_valor
# ALTO VALOR                    3815                  3815              3814
# MEDIO VALOR                   3806                  3806              3788
# OUTROS                        1617                  1617              1612
# RJ                            6824                  6824              6800
# SP                           11361                 11361             11339
#
#                ESTADO  COMARCA  CLASSIFICACAO  NATUREZA_OPERACIONAL  \
# cluster_valor
# ALTO VALOR       3815     3815           3801                  3607
# MEDIO VALOR      3806     3806           3777                  3630
# OUTROS           1572     1572           1572                  1536
# RJ               6824     6824           6792                  6571
# SP              11361    11361          11333                 10933
#
#                DATA_ADMISSAO  MES_DATA_ADMISSAO  DATA_DISPENSA  \
# cluster_valor
# ALTO VALOR              3692               3692           3603
# MEDIO VALOR             3660               3660           3577
# OUTROS                  1488               1488           1467
# RJ                      6641               6641           6475
# SP                     11107              11107          10821
#
#                MES_DATA_DISPENSA  DISTRIBUICAO  DISTRIBUICAO (ajustada)  \
# cluster_valor
# ALTO VALOR                  3603          3810                     3810
# MEDIO VALOR                 3577          3790                     3790
# OUTROS                      1467          1564                     1564
# RJ                          6475          6798                     6798
# SP                         10821         11341                    11340
#
#                PARTE_CONTRARIA_CARGO_GRUPO   FASE  FILIAL  BAND  NOME_DA_LOJA  \
# cluster_valor
# ALTO VALOR                            3802   3720    3815  2491          3041
# MEDIO VALOR                           3741   3740    3802  2655          3232
# OUTROS                                1548   1552    1617  1248          1471
# RJ                                    6773   6693    6810  3015          6041
# SP                                   11263  11165   11348  5844          8548
#
#                TIPO_BAND  ENCERRADOS  MOTIVO_ENCERRAMENTO  MES_FECH  \
# cluster_valor
# ALTO VALOR          3041        3815                 2434      3815
# MEDIO VALOR         3232        3806                 2639      3806
# OUTROS              1471        1623                 1155      1623
# RJ                  6041        6824                 4373      6824
# SP                  8548       11361                 7966     11361
#
#                MATRICULA  ACORDO  CONDENACAO  GARANTIA  PENHORA  IMPOSTO  \
# cluster_valor
# ALTO VALOR           176     706        1760      2078      156      556
# MEDIO VALOR          222    1531         971      1398      173      507
# OUTROS                68     860         275       283       39      259
# RJ                   429    1424        2333      3089      327      843
# SP                   740    3772        3127      4383      237     1946
#
#                OUTROS_PAGAMENTOS  TOTAL_PAGAMENTOS  MOTIVO_ENC_AGRP  \
# cluster_valor
# ALTO VALOR                   166              3249             3815
# MEDIO VALOR                   80              3206             3806
# OUTROS                        53              1302             1623
# RJ                           171              5105             6824
# SP                           188              9112            11361
#
#                CARGO AJUSTADO  Tempo de Empresa  \
# cluster_valor
# ALTO VALOR               3815              3602
# MEDIO VALOR              3806              3576
# OUTROS                   1623              1468
# RJ                       6824              6475
# SP                      11361             10822
#
#                Cluster Aging Tempo de Empresa  MESES_AGING_ENCERR  \
# cluster_valor
# ALTO VALOR                               3815                3815
# MEDIO VALOR                              3806                3806
# OUTROS                                   1623                1623
# RJ                                       6824                6824
# SP                                      11361               11361
#
#                Cluster Aging  Safra de Reclamação  TERCEIRO PRINCIPAL     ET  \
# cluster_valor
# ALTO VALOR              3815                 3815                 155   3815
# MEDIO VALOR             3806                 3806                 212   3806
# OUTROS                  1623                 1623                  55   1623
# RJ                      6824                 6824                1833   6824
# SP                     11361                11361                1043  11361
#
#                Distribuição  Data ULT_PGTO  Desindexador  \
# cluster_valor
# ALTO VALOR             3815           3815          3815
# MEDIO VALOR            3806           3806          3806
# OUTROS                 1623           1623          1623
# RJ                     6824           6824          6824
# SP                    11361          11361         11361
#
#                Pagamento Desindexado  OUTLIER
# cluster_valor
# ALTO VALOR                      3815     3815
# MEDIO VALOR                     3806     3806
# OUTROS                          1623     1623
# RJ                              6824     6824
# SP                             11361    11361

# %%
#Definição dos clusters
cluster_sp = ['SP']
cluster_rj = ['RJ']
cluster_alto_valor = ['MG', 'DF']
cluster_medio_valor = ['SC','PR','RS','BA','GO','MS'] 

#Criação de nova variável, agrupando os estados por perfil de faixa de valores
estoque['cluster_valor'] = estoque.ESTADO.apply(lambda x: 'ALTO VALOR' if x in cluster_alto_valor 
                                            else 'MEDIO VALOR' if x in cluster_medio_valor 
                                            else 'SP' if x in cluster_sp
                                            else 'RJ' if x in cluster_rj
                                            else 'OUTROS')

estoque.groupby(estoque['cluster_valor']).count()
# Out:
#                LINHA  ID PROCESSO  PASTA  Área do Direito  \
# cluster_valor
# ALTO VALOR      5312         5312    951             5312
# MEDIO VALOR     4077         4077    631             4077
# OUTROS          1742         1742     83             1742
# RJ              9916         9916   1958             9916
# SP             11682        11682   2477            11682
#
#                Sub-área do Direito  Grupo (M-1)  Empresa (M-1)  \
# cluster_valor
# ALTO VALOR                    5312            7           5193
# MEDIO VALOR                   4077           14           3880
# OUTROS                        1742            8           1583
# RJ                            9916           10           9744
# SP                           11682           19          11247
#
#                Grupo (Fechamento)  Empresa (M)  STATUS (M-1)  STATUS (M)  \
# cluster_valor
# ALTO VALOR                    124         5312          5193        5312
# MEDIO VALOR                   206         4077          3880        4077
# OUTROS                        163         1742          1583        1742
# RJ                            176         9916          9744        9916
# SP                            441        11682         11247       11682
#
#                  F12  Centro de Custo (M-1)  Centro de Custo (M)  Cadastro  \
# cluster_valor
# ALTO VALOR      5296                   5193                 5312      5312
# MEDIO VALOR     4043                   3880                 4077      4077
# OUTROS          1719                   1583                 1742      1742
# RJ              9876                   9744                 9916      9916
# SP             11555                  11247                11682     11682
#
#                Reabertura  Objeto Assunto/Cargo (M-1)  \
# cluster_valor
# ALTO VALOR             60                        5168
# MEDIO VALOR            55                        3815
# OUTROS                 15                        1538
# RJ                    152                        9696
# SP                    107                       11134
#
#                Sub Objeto Assunto/Cargo (M-1)  Objeto Assunto/Cargo (M)  \
# cluster_valor
# ALTO VALOR                               5074                      5287
# MEDIO VALOR                              3730                      4012
# OUTROS                                   1491                      1695
# RJ                                       9411                      9869
# SP                                      10650                     11566
#
#                Sub Objeto Assunto/Cargo (M)  Órgão ofensor (Fluxo) (M-1)  \
# cluster_valor
# ALTO VALOR                             5182                            0
# MEDIO VALOR                            3909                            0
# OUTROS                                 1637                            0
# RJ                                     9555                            0
# SP                                    11002                            0
#
#                Órgão ofensor (Fluxo) (M)  Natureza Operacional (M-1)  \
# cluster_valor
# ALTO VALOR                             0                        5135
# MEDIO VALOR                            0                        3838
# OUTROS                                 0                        1563
# RJ                                     0                        9688
# SP                                     0                       11125
#
#                Natureza Operacional (M)  Média de Pagamento  % Risco  \
# cluster_valor
# ALTO VALOR                         5254                5312     5312
# MEDIO VALOR                        4033                4077     4077
# OUTROS                             1721                1742     1742
# RJ                                 9856                9916     9916
# SP                                11557               11682    11682
#
#                Distribuição  Nº Processo  Escritorio  Vlr Causa  \
# cluster_valor
# ALTO VALOR             5312         5312        5312       5312
# MEDIO VALOR            4075         4077        4077       4077
# OUTROS                 1732         1742        1742       1742
# RJ                     9910         9916        9916       9916
# SP                    11681        11682       11682      11682
#
#                % Sócio (M-1)  % Empresa (M-1)  % Sócio (M)  % Empresa (M)  \
# cluster_valor
# ALTO VALOR              5312             5312         5312           5312
# MEDIO VALOR             4077             4077         4077           4077
# OUTROS                  1742             1742         1742           1742
# RJ                      9916             9916         9916           9916
# SP                     11682            11682        11682          11682
#
#                Provisão (M-1)  Correção  (M-1)  Provisão Total (M-1)  \
# cluster_valor
# ALTO VALOR               5312             5312                  5312
# MEDIO VALOR              4077             4077                  4077
# OUTROS                   1742             1742                  1742
# RJ                       9916             9916                  9916
# SP                      11682            11682                 11682
#
#                Classificação Mov. (M)  Provisão Mov. (M)  Correção Mov. (M)  \
# cluster_valor
# ALTO VALOR                       5312               5312               5312
# MEDIO VALOR                      4077               4077               4077
# OUTROS                           1742               1742               1742
# RJ                               9916               9916               9916
# SP                              11682              11682              11682
#
#                Provisão Mov. Total (M)  Provisão Total (M)  Correção (M-1)  \
# cluster_valor
# ALTO VALOR                        5312                5312            5312
# MEDIO VALOR                       4077                4077            4077
# OUTROS                            1742                1742            1742
# RJ                                9916                9916            9916
# SP                               11682               11682           11682
#
#                Correção (M)  Provisão Total Passivo (M)  \
# cluster_valor
# ALTO VALOR             5312                        5312
# MEDIO VALOR            4077                        4077
# OUTROS                 1742                        1742
# RJ                     9916                        9916
# SP                    11682                       11682
#
#                Demitido por Reestruturação  Indicação Processo Estratégico  \
# cluster_valor
# ALTO VALOR                            5304                            2679
# MEDIO VALOR                           4067                            2544
# OUTROS                                1716                            1322
# RJ                                    9864                            5045
# SP                                   11665                            6583
#
#                Filial (M)  Novos  Encerrados  Estoque  CADASTRO_AJUSTADO  \
# cluster_valor
# ALTO VALOR              0   5312        5312     5312               5312
# MEDIO VALOR             0   4077        4077     4077               4077
# OUTROS                  0   1742        1742     1742               1742
# RJ                      0   9916        9916     9916               9916
# SP                      0  11682       11682    11682              11682
#
#                MES_CADASTRO  DISTRIBUICAO  MES_DISTRIBUICAO   FASE  \
# cluster_valor
# ALTO VALOR             5312          5312              5312   5268
# MEDIO VALOR            4077          4075              4075   4065
# OUTROS                 1742          1732              1732   1720
# RJ                     9916          9910              9910   9846
# SP                    11682         11681             11681  11605
#
#                DE_PARA_FASE  ESTADO  TERCEIRO_PRINCIPAL  NOVO_TERCEIRO  \
# cluster_valor
# ALTO VALOR             5312    5312                 163            370
# MEDIO VALOR            4077    4077                 257            339
# OUTROS                 1742    1732                  46            114
# RJ                     9916    9916                2985           4058
# SP                    11682   11682                1042           2340
#
#                PARTE_CONTRARIA_CPF  DATA_ADMISSAO  MES_FECH  DATA_DISPENSA  \
# cluster_valor
# ALTO VALOR                    5312           5236      5312           4914
# MEDIO VALOR                   4077           4012      4077           3712
# OUTROS                        1742           1657      1742           1465
# RJ                            9916           9704      9916           9093
# SP                           11682          11522     11682          10824
#
#                MES_DATA_ADMISSAO  MES_DATA_DISPENSA  TEMPO_EMPRESA_MESES  \
# cluster_valor
# ALTO VALOR                  5236               4914                 4913
# MEDIO VALOR                 4012               3712                 3712
# OUTROS                      1657               1465                 1464
# RJ                          9704               9093                 9092
# SP                         11522              10824                10822
#
#                MESES_AGING_ESTOQ  FX_MES_AGING_ESTOQ  FX_ANO_AGING_ESTOQ  \
# cluster_valor
# ALTO VALOR                  5312                5312                5312
# MEDIO VALOR                 4077                4077                4077
# OUTROS                      1742                1742                1742
# RJ                          9916                9916                9916
# SP                         11682               11682               11682
#
#                Cluster Aging Tempo de Empresa  Cluster Aging  \
# cluster_valor
# ALTO VALOR                               5312           5312
# MEDIO VALOR                              4077           4077
# OUTROS                                   1742           1742
# RJ                                       9916           9916
# SP                                      11682          11682
#
#                Safra de Reclamação     ET
# cluster_valor
# ALTO VALOR                    5312   5312
# MEDIO VALOR                   4077   4077
# OUTROS                        1742   1742
# RJ                            9916   9916
# SP                           11678  11682

# %%
#Gerar o agrupamento de cargos definido como objeto do estudo
lista_cargos = ['VENDEDOR','MONTADOR','AJUDANTE', 'GERENTE', 'MOTORISTA','AJUDANTE EXTERNO', 'CAIXA','OPERADOR','AUXILIAR','ANALISTA']

dados['cargo_tratado'] = dados.PARTE_CONTRARIA_CARGO_GRUPO.apply(lambda x: x if x in lista_cargos else 'OUTROS')

dados.groupby(dados.cargo_tratado).count()
# Out:
#                   ID_PROCESSO  CADASTRO  MES_CADASTRO  AREA_DO_DIREITO  \
# cargo_tratado
# AJUDANTE                 2435      2435          2435             2435
# AJUDANTE EXTERNO         1288      1288          1288             1288
# ANALISTA                  646       646           646              646
# AUXILIAR                 1678      1678          1678             1678
# CAIXA                     991       991           991              991
# GERENTE                   657       657           657              657
# MONTADOR                 3504      3504          3504             3504
# MOTORISTA                1241      1241          1241             1241
# OPERADOR                  774       774           774              774
# OUTROS                   4750      4750          4750             4744
# VENDEDOR                 9465      9465          9465             9465
#
#                   SUB_AREA_DO_DIREITO  VALOR_DA_CAUSA  ESCRITORIO_RESPONSAVEL  \
# cargo_tratado
# AJUDANTE                         2435            2434                    2435
# AJUDANTE EXTERNO                 1288            1288                    1288
# ANALISTA                          646             646                     646
# AUXILIAR                         1678            1678                    1678
# CAIXA                             991             990                     991
# GERENTE                           657             656                     657
# MONTADOR                         3504            3504                    3504
# MOTORISTA                        1241            1239                    1241
# OPERADOR                          774             773                     774
# OUTROS                           4744            4695                    4744
# VENDEDOR                         9465            9464                    9465
#
#                   PARTE_CONTRARIA_CPF  PARTE_CONTRARIA_NOME  PROCESSO_ESTEIRA  \
# cargo_tratado
# AJUDANTE                         2435                  2435              2432
# AJUDANTE EXTERNO                 1288                  1288              1283
# ANALISTA                          646                   646               645
# AUXILIAR                         1678                  1678              1674
# CAIXA                             991                   991               990
# GERENTE                           657                   657               655
# MONTADOR                         3504                  3504              3503
# MOTORISTA                        1241                  1241              1229
# OPERADOR                          774                   774               772
# OUTROS                           4744                  4744              4718
# VENDEDOR                         9465                  9465              9452
#
#                   ESTADO  COMARCA  CLASSIFICACAO  NATUREZA_OPERACIONAL  \
# cargo_tratado
# AJUDANTE            2435     2435           2432                  2378
# AJUDANTE EXTERNO    1288     1288           1283                  1230
# ANALISTA             646      646            645                   610
# AUXILIAR            1678     1678           1673                  1618
# CAIXA                991      991            990                   956
# GERENTE              657      657            655                   625
# MONTADOR            3504     3504           3502                  3361
# MOTORISTA           1241     1241           1229                  1183
# OPERADOR             773      773            773                   741
# OUTROS              4701     4701           4643                  4539
# VENDEDOR            9464     9464           9450                  9036
#
#                   DATA_ADMISSAO  MES_DATA_ADMISSAO  DATA_DISPENSA  \
# cargo_tratado
# AJUDANTE                   2388               2388           2350
# AJUDANTE EXTERNO           1287               1287           1264
# ANALISTA                    646                646            633
# AUXILIAR                   1674               1674           1605
# CAIXA                       991                991            967
# GERENTE                     656                656            651
# MONTADOR                   3500               3500           3437
# MOTORISTA                  1240               1240           1218
# OPERADOR                    773                773            755
# OUTROS                     3989               3989           3763
# VENDEDOR                   9444               9444           9300
#
#                   MES_DATA_DISPENSA  DISTRIBUICAO  DISTRIBUICAO (ajustada)  \
# cargo_tratado
# AJUDANTE                       2350          2434                     2434
# AJUDANTE EXTERNO               1264          1288                     1288
# ANALISTA                        633           646                      646
# AUXILIAR                       1605          1678                     1678
# CAIXA                           967           990                      990
# GERENTE                         651           657                      657
# MONTADOR                       3437          3504                     3504
# MOTORISTA                      1218          1238                     1238
# OPERADOR                        755           773                      772
# OUTROS                         3763          4631                     4631
# VENDEDOR                       9300          9464                     9464
#
#                   PARTE_CONTRARIA_CARGO_GRUPO  FASE  FILIAL  BAND  \
# cargo_tratado
# AJUDANTE                                 2435  2435    2428   271
# AJUDANTE EXTERNO                         1288  1288    1287   183
# ANALISTA                                  646   646     646   416
# AUXILIAR                                 1678  1678    1677   868
# CAIXA                                     991   991     990   899
# GERENTE                                   657   657     657   492
# MONTADOR                                 3504  3504    3503  1500
# MOTORISTA                                1241  1241    1239   134
# OPERADOR                                  774   774     773    43
# OUTROS                                   4448  4192    4727  2364
# VENDEDOR                                 9465  9464    9465  8083
#
#                   NOME_DA_LOJA  TIPO_BAND  ENCERRADOS  MOTIVO_ENCERRAMENTO  \
# cargo_tratado
# AJUDANTE                  2135       2135        2435                 1515
# AJUDANTE EXTERNO          1146       1146        1288                  833
# ANALISTA                   443        443         646                  451
# AUXILIAR                  1300       1300        1678                 1204
# CAIXA                      909        909         991                  749
# GERENTE                    498        498         657                  458
# MONTADOR                  2550       2550        3504                 2096
# MOTORISTA                 1112       1112        1241                  778
# OPERADOR                   565        565         774                  502
# OUTROS                    3556       3556        4750                 3494
# VENDEDOR                  8119       8119        9465                 6487
#
#                   MES_FECH  MATRICULA  ACORDO  CONDENACAO  GARANTIA  PENHORA  \
# cargo_tratado
# AJUDANTE              2435        197     392         953       987      125
# AJUDANTE EXTERNO      1288         82      84         431       736       66
# ANALISTA               646         46     183         251       312       28
# AUXILIAR              1678        121     652         447       509       39
# CAIXA                  991         57     565         209       218       22
# GERENTE                657         36     251         198       318       18
# MONTADOR              3504        202     527        1578      2083      154
# MOTORISTA             1241         53     226         359       626       53
# OPERADOR               774         40     241         245       276       23
# OUTROS                4750        293    1273         953      1120      107
# VENDEDOR              9465        508    3899        2842      4046      297
#
#                   IMPOSTO  OUTROS_PAGAMENTOS  TOTAL_PAGAMENTOS  \
# cargo_tratado
# AJUDANTE              258                 23              1698
# AJUDANTE EXTERNO      152                 25               897
# ANALISTA              135                 10               557
# AUXILIAR              289                 11              1332
# CAIXA                 152                  6               869
# GERENTE               170                 16               560
# MONTADOR              586                 58              2909
# MOTORISTA             162                 20               938
# OPERADOR              174                  8               603
# OUTROS                540                343              3078
# VENDEDOR             1493                138              8533
#
#                   MOTIVO_ENC_AGRP  CARGO AJUSTADO  Tempo de Empresa  \
# cargo_tratado
# AJUDANTE                     2435            2435              2351
# AJUDANTE EXTERNO             1288            1288              1264
# ANALISTA                      646             646               633
# AUXILIAR                     1678            1678              1604
# CAIXA                         991             991               967
# GERENTE                       657             657               651
# MONTADOR                     3504            3504              3437
# MOTORISTA                    1241            1241              1219
# OPERADOR                      774             774               755
# OUTROS                       4750            4750              3761
# VENDEDOR                     9465            9465              9301
#
#                   Cluster Aging Tempo de Empresa  MESES_AGING_ENCERR  \
# cargo_tratado
# AJUDANTE                                    2435                2435
# AJUDANTE EXTERNO                            1288                1288
# ANALISTA                                     646                 646
# AUXILIAR                                    1678                1678
# CAIXA                                        991                 991
# GERENTE                                      657                 657
# MONTADOR                                    3504                3504
# MOTORISTA                                   1241                1241
# OPERADOR                                     774                 774
# OUTROS                                      4750                4750
# VENDEDOR                                    9465                9465
#
#                   Cluster Aging  Safra de Reclamação  TERCEIRO PRINCIPAL  \
# cargo_tratado
# AJUDANTE                   2435                 2435                1041
# AJUDANTE EXTERNO           1288                 1288                 411
# ANALISTA                    646                  646                  64
# AUXILIAR                   1678                 1678                 266
# CAIXA                       991                  991                  20
# GERENTE                     657                  657                   8
# MONTADOR                   3504                 3504                 319
# MOTORISTA                  1241                 1241                 268
# OPERADOR                    774                  774                  68
# OUTROS                     4750                 4750                 740
# VENDEDOR                   9465                 9465                  93
#
#                     ET  Distribuição  Data ULT_PGTO  Desindexador  \
# cargo_tratado
# AJUDANTE          2435          2435           2435          2435
# AJUDANTE EXTERNO  1288          1288           1288          1288
# ANALISTA           646           646            646           646
# AUXILIAR          1678          1678           1678          1678
# CAIXA              991           991            991           991
# GERENTE            657           657            657           657
# MONTADOR          3504          3504           3504          3504
# MOTORISTA         1241          1241           1241          1241
# OPERADOR           774           774            774           774
# OUTROS            4750          4750           4750          4750
# VENDEDOR          9465          9465           9465          9465
#
#                   Pagamento Desindexado  OUTLIER  cluster_valor
# cargo_tratado
# AJUDANTE                           2435     2435           2435
# AJUDANTE EXTERNO                   1288     1288           1288
# ANALISTA                            646      646            646
# AUXILIAR                           1678     1678           1678
# CAIXA                               991      991            991
# GERENTE                             657      657            657
# MONTADOR                           3504     3504           3504
# MOTORISTA                          1241     1241           1241
# OPERADOR                            774      774            774
# OUTROS                             4750     4750           4750
# VENDEDOR                           9465     9465           9465

# %%
#Gerar o agrupamento de cargos definido como objeto do estudo
lista_cargos_estoque = ['VENDEDOR','MONTADOR','AJUDANTE', 'GERENTE', 'MOTORISTA','AJUDANTE EXTERNO', 'CAIXA','OPERADOR','AUXILIAR','ANALISTA']

estoque['cargo_tratado'] = estoque['Objeto Assunto/Cargo (M)'].apply(lambda x: x if x in lista_cargos else 'OUTROS')

estoque.groupby(estoque.cargo_tratado).count()
# Out:
#                   LINHA  ID PROCESSO  PASTA  Área do Direito  \
# cargo_tratado
# AJUDANTE           3047         3047    381             3047
# AJUDANTE EXTERNO   1596         1596    636             1596
# ANALISTA            651          651    122              651
# AUXILIAR           1822         1822    286             1822
# CAIXA              1009         1009     72             1009
# GERENTE            1002         1002    159             1002
# MONTADOR           4438         4438    923             4438
# MOTORISTA          1454         1454    527             1454
# OPERADOR            979          979    225              979
# OUTROS             5760         5760    748             5760
# VENDEDOR          10971        10971   2021            10971
#
#                   Sub-área do Direito  Grupo (M-1)  Empresa (M-1)  \
# cargo_tratado
# AJUDANTE                         3047            5           2994
# AJUDANTE EXTERNO                 1596            5           1590
# ANALISTA                          651            0            647
# AUXILIAR                         1822            9           1730
# CAIXA                            1009            2            947
# GERENTE                          1002            0            985
# MONTADOR                         4438            0           4336
# MOTORISTA                        1454            2           1436
# OPERADOR                          979            0            951
# OUTROS                           5760           13           5467
# VENDEDOR                        10971           22          10564
#
#                   Grupo (Fechamento)  Empresa (M)  STATUS (M-1)  STATUS (M)  \
# cargo_tratado
# AJUDANTE                          56         3047          2994        3047
# AJUDANTE EXTERNO                  10         1596          1590        1596
# ANALISTA                           3          651           647         651
# AUXILIAR                          98         1822          1730        1822
# CAIXA                             62         1009           947        1009
# GERENTE                           17         1002           985        1002
# MONTADOR                          96         4438          4336        4438
# MOTORISTA                         19         1454          1436        1454
# OPERADOR                          28          979           951         979
# OUTROS                           301         5760          5467        5760
# VENDEDOR                         420        10971         10564       10971
#
#                     F12  Centro de Custo (M-1)  Centro de Custo (M)  Cadastro  \
# cargo_tratado
# AJUDANTE           3036                   2994                 3047      3047
# AJUDANTE EXTERNO   1595                   1590                 1596      1596
# ANALISTA            647                    647                  651       651
# AUXILIAR           1805                   1730                 1822      1822
# CAIXA               999                    947                 1009      1009
# GERENTE             999                    985                 1002      1002
# MONTADOR           4415                   4336                 4438      4438
# MOTORISTA          1450                   1436                 1454      1454
# OPERADOR            966                    951                  979       979
# OUTROS             5685                   5467                 5760      5760
# VENDEDOR          10892                  10564                10971     10971
#
#                   Reabertura  Objeto Assunto/Cargo (M-1)  \
# cargo_tratado
# AJUDANTE                  49                        2993
# AJUDANTE EXTERNO          41                        1590
# ANALISTA                  10                         647
# AUXILIAR                  28                        1730
# CAIXA                      6                         947
# GERENTE                   16                         985
# MONTADOR                  53                        4336
# MOTORISTA                 14                        1436
# OPERADOR                  10                         951
# OUTROS                    65                        5173
# VENDEDOR                  97                       10563
#
#                   Sub Objeto Assunto/Cargo (M-1)  Objeto Assunto/Cargo (M)  \
# cargo_tratado
# AJUDANTE                                    2873                      3047
# AJUDANTE EXTERNO                            1567                      1596
# ANALISTA                                     636                       651
# AUXILIAR                                    1707                      1822
# CAIXA                                        934                      1009
# GERENTE                                      985                      1002
# MONTADOR                                    4279                      4438
# MOTORISTA                                   1378                      1454
# OPERADOR                                     941                       979
# OUTROS                                      4645                      5460
# VENDEDOR                                   10411                     10971
#
#                   Sub Objeto Assunto/Cargo (M)  Órgão ofensor (Fluxo) (M-1)  \
# cargo_tratado
# AJUDANTE                                  2912                            0
# AJUDANTE EXTERNO                          1572                            0
# ANALISTA                                   640                            0
# AUXILIAR                                  1786                            0
# CAIXA                                      991                            0
# GERENTE                                   1002                            0
# MONTADOR                                  4337                            0
# MOTORISTA                                 1385                            0
# OPERADOR                                   967                            0
# OUTROS                                    4898                            0
# VENDEDOR                                 10795                            0
#
#                   Órgão ofensor (Fluxo) (M)  Natureza Operacional (M-1)  \
# cargo_tratado
# AJUDANTE                                  0                        2982
# AJUDANTE EXTERNO                          0                        1568
# ANALISTA                                  0                         637
# AUXILIAR                                  0                        1716
# CAIXA                                     0                         941
# GERENTE                                   0                         975
# MONTADOR                                  0                        4295
# MOTORISTA                                 0                        1416
# OPERADOR                                  0                         939
# OUTROS                                    0                        5414
# VENDEDOR                                  0                       10466
#
#                   Natureza Operacional (M)  Média de Pagamento  % Risco  \
# cargo_tratado
# AJUDANTE                              3034                3047     3047
# AJUDANTE EXTERNO                      1573                1596     1596
# ANALISTA                               641                 651      651
# AUXILIAR                              1806                1822     1822
# CAIXA                                 1003                1009     1009
# GERENTE                                992                1002     1002
# MONTADOR                              4397                4438     4438
# MOTORISTA                             1434                1454     1454
# OPERADOR                               967                 979      979
# OUTROS                                5706                5760     5760
# VENDEDOR                             10868               10971    10971
#
#                   Distribuição  Nº Processo  Escritorio  Vlr Causa  \
# cargo_tratado
# AJUDANTE                  3047         3047        3047       3047
# AJUDANTE EXTERNO          1596         1596        1596       1596
# ANALISTA                   651          651         651        651
# AUXILIAR                  1822         1822        1822       1822
# CAIXA                     1009         1009        1009       1009
# GERENTE                   1002         1002        1002       1002
# MONTADOR                  4438         4438        4438       4438
# MOTORISTA                 1454         1454        1454       1454
# OPERADOR                   979          979         979        979
# OUTROS                    5741         5760        5760       5760
# VENDEDOR                 10971        10971       10971      10971
#
#                   % Sócio (M-1)  % Empresa (M-1)  % Sócio (M)  % Empresa (M)  \
# cargo_tratado
# AJUDANTE                   3047             3047         3047           3047
# AJUDANTE EXTERNO           1596             1596         1596           1596
# ANALISTA                    651              651          651            651
# AUXILIAR                   1822             1822         1822           1822
# CAIXA                      1009             1009         1009           1009
# GERENTE                    1002             1002         1002           1002
# MONTADOR                   4438             4438         4438           4438
# MOTORISTA                  1454             1454         1454           1454
# OPERADOR                    979              979          979            979
# OUTROS                     5760             5760         5760           5760
# VENDEDOR                  10971            10971        10971          10971
#
#                   Provisão (M-1)  Correção  (M-1)  Provisão Total (M-1)  \
# cargo_tratado
# AJUDANTE                    3047             3047                  3047
# AJUDANTE EXTERNO            1596             1596                  1596
# ANALISTA                     651              651                   651
# AUXILIAR                    1822             1822                  1822
# CAIXA                       1009             1009                  1009
# GERENTE                     1002             1002                  1002
# MONTADOR                    4438             4438                  4438
# MOTORISTA                   1454             1454                  1454
# OPERADOR                     979              979                   979
# OUTROS                      5760             5760                  5760
# VENDEDOR                   10971            10971                 10971
#
#                   Classificação Mov. (M)  Provisão Mov. (M)  \
# cargo_tratado
# AJUDANTE                            3047               3047
# AJUDANTE EXTERNO                    1596               1596
# ANALISTA                             651                651
# AUXILIAR                            1822               1822
# CAIXA                               1009               1009
# GERENTE                             1002               1002
# MONTADOR                            4438               4438
# MOTORISTA                           1454               1454
# OPERADOR                             979                979
# OUTROS                              5760               5760
# VENDEDOR                           10971              10971
#
#                   Correção Mov. (M)  Provisão Mov. Total (M)  \
# cargo_tratado
# AJUDANTE                       3047                     3047
# AJUDANTE EXTERNO               1596                     1596
# ANALISTA                        651                      651
# AUXILIAR                       1822                     1822
# CAIXA                          1009                     1009
# GERENTE                        1002                     1002
# MONTADOR                       4438                     4438
# MOTORISTA                      1454                     1454
# OPERADOR                        979                      979
# OUTROS                         5760                     5760
# VENDEDOR                      10971                    10971
#
#                   Provisão Total (M)  Correção (M-1)  Correção (M)  \
# cargo_tratado
# AJUDANTE                        3047            3047          3047
# AJUDANTE EXTERNO                1596            1596          1596
# ANALISTA                         651             651           651
# AUXILIAR                        1822            1822          1822
# CAIXA                           1009            1009          1009
# GERENTE                         1002            1002          1002
# MONTADOR                        4438            4438          4438
# MOTORISTA                       1454            1454          1454
# OPERADOR                         979             979           979
# OUTROS                          5760            5760          5760
# VENDEDOR                       10971           10971         10971
#
#                   Provisão Total Passivo (M)  Demitido por Reestruturação  \
# cargo_tratado
# AJUDANTE                                3047                         3047
# AJUDANTE EXTERNO                        1596                         1596
# ANALISTA                                 651                          651
# AUXILIAR                                1822                         1822
# CAIXA                                   1009                         1009
# GERENTE                                 1002                         1002
# MONTADOR                                4438                         4438
# MOTORISTA                               1454                         1454
# OPERADOR                                 979                          979
# OUTROS                                  5760                         5647
# VENDEDOR                               10971                        10971
#
#                   Indicação Processo Estratégico  Filial (M)  Novos  \
# cargo_tratado
# AJUDANTE                                    1661           0   3047
# AJUDANTE EXTERNO                             688           0   1596
# ANALISTA                                     298           0    651
# AUXILIAR                                    1159           0   1822
# CAIXA                                        768           0   1009
# GERENTE                                      545           0   1002
# MONTADOR                                    1843           0   4438
# MOTORISTA                                    625           0   1454
# OPERADOR                                     559           0    979
# OUTROS                                      3670           0   5760
# VENDEDOR                                    6357           0  10971
#
#                   Encerrados  Estoque  CADASTRO_AJUSTADO  MES_CADASTRO  \
# cargo_tratado
# AJUDANTE                3047     3047               3047          3047
# AJUDANTE EXTERNO        1596     1596               1596          1596
# ANALISTA                 651      651                651           651
# AUXILIAR                1822     1822               1822          1822
# CAIXA                   1009     1009               1009          1009
# GERENTE                 1002     1002               1002          1002
# MONTADOR                4438     4438               4438          4438
# MOTORISTA               1454     1454               1454          1454
# OPERADOR                 979      979                979           979
# OUTROS                  5760     5760               5760          5760
# VENDEDOR               10971    10971              10971         10971
#
#                   DISTRIBUICAO  MES_DISTRIBUICAO   FASE  DE_PARA_FASE  ESTADO  \
# cargo_tratado
# AJUDANTE                  3047              3047   3047          3047    3046
# AJUDANTE EXTERNO          1596              1596   1596          1596    1596
# ANALISTA                   651               651    651           651     651
# AUXILIAR                  1822              1822   1822          1822    1822
# CAIXA                     1009              1009   1009          1009    1009
# GERENTE                   1002              1002   1002          1002    1002
# MONTADOR                  4438              4438   4438          4438    4438
# MOTORISTA                 1454              1454   1454          1454    1454
# OPERADOR                   979               979    979           979     979
# OUTROS                    5741              5741   5536          5760    5751
# VENDEDOR                 10971             10971  10970         10971   10971
#
#                   TERCEIRO_PRINCIPAL  NOVO_TERCEIRO  PARTE_CONTRARIA_CPF  \
# cargo_tratado
# AJUDANTE                        1472           1918                 3047
# AJUDANTE EXTERNO                 621            920                 1596
# ANALISTA                         113            142                  651
# AUXILIAR                         247            442                 1822
# CAIXA                             14             21                 1009
# GERENTE                           14             16                 1002
# MONTADOR                         439           1203                 4438
# MOTORISTA                        442            587                 1454
# OPERADOR                          65            124                  979
# OUTROS                           924           1710                 5760
# VENDEDOR                         142            138                10971
#
#                   DATA_ADMISSAO  MES_FECH  DATA_DISPENSA  MES_DATA_ADMISSAO  \
# cargo_tratado
# AJUDANTE                   3027      3047           2922               3027
# AJUDANTE EXTERNO           1596      1596           1527               1596
# ANALISTA                    651       651            640                651
# AUXILIAR                   1819      1822           1603               1819
# CAIXA                      1009      1009            900               1009
# GERENTE                    1002      1002            992               1002
# MONTADOR                   4432      4438           4333               4432
# MOTORISTA                  1451      1454           1356               1451
# OPERADOR                    979       979            859                979
# OUTROS                     5211      5760           4762               5211
# VENDEDOR                  10954     10971          10114              10954
#
#                   MES_DATA_DISPENSA  TEMPO_EMPRESA_MESES  MESES_AGING_ESTOQ  \
# cargo_tratado
# AJUDANTE                       2922                 2921               3047
# AJUDANTE EXTERNO               1527                 1527               1596
# ANALISTA                        640                  640                651
# AUXILIAR                       1603                 1603               1822
# CAIXA                           900                  900               1009
# GERENTE                         992                  992               1002
# MONTADOR                       4333                 4333               4438
# MOTORISTA                      1356                 1356               1454
# OPERADOR                        859                  859                979
# OUTROS                         4762                 4758               5760
# VENDEDOR                      10114                10114              10971
#
#                   FX_MES_AGING_ESTOQ  FX_ANO_AGING_ESTOQ  \
# cargo_tratado
# AJUDANTE                        3047                3047
# AJUDANTE EXTERNO                1596                1596
# ANALISTA                         651                 651
# AUXILIAR                        1822                1822
# CAIXA                           1009                1009
# GERENTE                         1002                1002
# MONTADOR                        4438                4438
# MOTORISTA                       1454                1454
# OPERADOR                         979                 979
# OUTROS                          5760                5760
# VENDEDOR                       10971               10971
#
#                   Cluster Aging Tempo de Empresa  Cluster Aging  \
# cargo_tratado
# AJUDANTE                                    3047           3047
# AJUDANTE EXTERNO                            1596           1596
# ANALISTA                                     651            651
# AUXILIAR                                    1822           1822
# CAIXA                                       1009           1009
# GERENTE                                     1002           1002
# MONTADOR                                    4438           4438
# MOTORISTA                                   1454           1454
# OPERADOR                                     979            979
# OUTROS                                      5760           5760
# VENDEDOR                                   10971          10971
#
#                   Safra de Reclamação     ET  cluster_valor
# cargo_tratado
# AJUDANTE                         3047   3047           3047
# AJUDANTE EXTERNO                 1596   1596           1596
# ANALISTA                          651    651            651
# AUXILIAR                         1822   1822           1822
# CAIXA                            1009   1009           1009
# GERENTE                          1002   1002           1002
# MONTADOR                         4436   4438           4438
# MOTORISTA                        1453   1454           1454
# OPERADOR                          979    979            979
# OUTROS                           5759   5760           5760
# VENDEDOR                        10971  10971          10971

# %%
dados_condenacao_geral = estoque

# %%
natureza_notin = ['TERCEIRO INSOLVENTE']
sub_area_direito_notin = ['PREVENTIVO AUTO DE INFRAÇÃO','CONTENCIOSO COLETIVO']
Outlier_notin = ['Outlier']

dados_condenacao_cargo = dados[(dados['MOTIVO_ENC_AGRP'] == 'CONDENACAO')
                        & (dados['NATUREZA_OPERACIONAL'].isin(natureza_notin))
                        & (~dados['SUB_AREA_DO_DIREITO'].isin(sub_area_direito_notin))
                        & (~dados['OUTLIER'].isin(Outlier_notin))       
                       ]
                       
len(dados_condenacao_cargo)
# Out:
# 1291

# %%
#Define o filtro para Vendedor TREINO
estoque_cargo = estoque[(estoque['Natureza Operacional (M)'] == "TERCEIRO INSOLVENTE")]

len(estoque_cargo)
# Out:
# 3243

# %%
len(estoque)
# Out:
# 32729

# %% [markdown]
# ## Label Encoder
#
# Transformar as variáveis categóricas em labels codificados para utilização dos modelos - requisito.
#
# ## Preparação dos dataframes com as Variáveis Explicativas e com a Variável Resposta

# %%
#Cria um novo dataframe adequado ao scikit-learning para treinamento dos modelos
explicativas = pd.DataFrame()
explicativas['ID PROCESSO'] = dados_condenacao_geral['ID PROCESSO']
explicativas_cargo = pd.DataFrame()
explicativas_cargo['ID_PROCESSO'] = dados_condenacao_cargo.ID_PROCESSO

explicativas_estoque = pd.DataFrame()
explicativas_estoque['ID PROCESSO'] = estoque_cargo['ID PROCESSO']



#Faz o Label Encoder, que converte dados qualitativos de texto para um índice numérico
#Com esse encoding, podemos facilmente voltar aos valores originais utilizando a função inverse_transform

#adiciona a variável Estado codificada ao dataframe
le_estado = preprocessing.LabelEncoder()
encode_estado = le_estado.fit(estoque['ESTADO'])
explicativas['ESTADO'] = encode_estado.transform(dados_condenacao_geral['ESTADO'])
explicativas_cargo['ESTADO'] = encode_estado.transform(dados_condenacao_cargo['ESTADO'])
explicativas_estoque['ESTADO'] = encode_estado.transform(estoque_cargo['ESTADO'])


#gera o de-para dos estados
estados = pd.DataFrame()
estados['codigos'] = explicativas_estoque.ESTADO.unique()
estados['estados'] = encode_estado.inverse_transform(estados.codigos)
estados.sort_values(by='codigos')
# Out:
#     codigos estados
# 6         1      BA
# 5         3      DF
# 4         4      ES
# 10        5      GO
# 13        6      MA
# 3         7      MG
# 9         8      MS
# 14        9      MT
# 2        12      PE
# 8        14      PR
# 0        15      RJ
# 7        17      RS
# 12       18      SC
# 11       19      SE
# 1        20      SP

# %%
#adiciona a variável cluster valor codificada ao dataframe
le_cluster_valor = preprocessing.LabelEncoder()
encode_cluster_valor = le_cluster_valor.fit(dados_condenacao_geral['cluster_valor'])
explicativas['cluster_valor'] = encode_cluster_valor.transform(dados_condenacao_geral['cluster_valor'])
explicativas_cargo['cluster_valor'] = encode_cluster_valor.transform(dados_condenacao_cargo['cluster_valor'])
explicativas_estoque['cluster_valor'] = encode_cluster_valor.transform(estoque_cargo['cluster_valor'])

#gera o de-para dos cluster valor
cluster_valor = pd.DataFrame()
cluster_valor['codigos'] = explicativas.cluster_valor.unique()
cluster_valor['cluster_valor'] = encode_cluster_valor.inverse_transform(cluster_valor.codigos)
cluster_valor.sort_values(by='codigos')
# Out:
#    codigos cluster_valor
# 3        0    ALTO VALOR
# 4        1   MEDIO VALOR
# 2        2        OUTROS
# 1        3            RJ
# 0        4            SP

# %%
#adiciona a variável cargo_tratado codificada ao dataframe
le_cargo_tratado = preprocessing.LabelEncoder()
encode_cargo_tratado = le_cargo_tratado.fit(dados_condenacao_geral['cargo_tratado'])
explicativas['cargo_tratado'] = encode_cargo_tratado.transform(dados_condenacao_geral['cargo_tratado'])
explicativas_cargo['cargo_tratado'] = encode_cargo_tratado.transform(dados_condenacao_cargo['cargo_tratado'])
explicativas_estoque['cargo_tratado'] = encode_cargo_tratado.transform(estoque_cargo['cargo_tratado'])


#gera o de-para dos cargos
cargo = pd.DataFrame()
cargo['codigos'] = explicativas.cargo_tratado.unique()
cargo['cargo'] = encode_cargo_tratado.inverse_transform(cargo.codigos)
cargo.sort_values(by='codigos')
# Out:
#     codigos             cargo
# 1         0          AJUDANTE
# 7         1  AJUDANTE EXTERNO
# 2         2          ANALISTA
# 0         3          AUXILIAR
# 10        4             CAIXA
# 9         5           GERENTE
# 5         6          MONTADOR
# 6         7         MOTORISTA
# 8         8          OPERADOR
# 3         9            OUTROS
# 4        10          VENDEDOR

# %%
#adiciona a variável Cluster Aging Tempo de Empresa codificada ao dataframe
le_tempo_empresa = preprocessing.LabelEncoder()
encode_tempo_empresa = le_tempo_empresa.fit(dados_condenacao_geral['Cluster Aging Tempo de Empresa'])
explicativas['Cluster Aging Tempo de Empresa'] = encode_tempo_empresa.transform(dados_condenacao_geral['Cluster Aging Tempo de Empresa'])
explicativas_cargo['Cluster Aging Tempo de Empresa'] = encode_tempo_empresa.transform(dados_condenacao_cargo['Cluster Aging Tempo de Empresa'])
explicativas_estoque['Cluster Aging Tempo de Empresa'] = encode_tempo_empresa.transform(estoque_cargo['Cluster Aging Tempo de Empresa'])

#gera o de-para dos cluster tempo de empresa
tempo_empresa = pd.DataFrame()
tempo_empresa['codigos'] = explicativas['Cluster Aging Tempo de Empresa'].unique()
tempo_empresa['tempo_empresa'] = encode_tempo_empresa.inverse_transform(tempo_empresa.codigos)
tempo_empresa.sort_values(by='codigos')
# Out:
#    codigos     tempo_empresa
# 5        0        1 - 2 anos
# 6        1        2 - 3 anos
# 3        2        3 - 4 anos
# 4        3        4 - 5 anos
# 2        4        5 - 6 anos
# 1        5       6 - 10 anos
# 8        6  Acima de 10 anos
# 0        7         Até 1 ano
# 7        8          Sem info

# %%
#adiciona a variável Cluster Aging codificada ao dataframe
le_cluster_aging = preprocessing.LabelEncoder()
encode_cluster_aging = le_cluster_aging.fit(dados_condenacao_geral['Cluster Aging'])
explicativas['Cluster Aging'] = encode_cluster_aging.transform(dados_condenacao_geral['Cluster Aging'])
explicativas_cargo['Cluster Aging'] = encode_cluster_aging.transform(dados_condenacao_cargo['Cluster Aging'])
explicativas_estoque['Cluster Aging'] = encode_cluster_aging.transform(estoque_cargo['Cluster Aging'])

#gera o de-para dos cluster aging
cluster_aging = pd.DataFrame()
cluster_aging['codigos'] = explicativas['Cluster Aging'].unique()
cluster_aging['cluster_aging'] = encode_cluster_aging.inverse_transform(cluster_aging.codigos)
cluster_aging.sort_values(by='codigos')
# Out:
#    codigos cluster_aging
# 0        0       +7 ANOS
# 6        1    1 - 2 ANOS
# 5        2    2 - 3 ANOS
# 4        3    3 - 4 ANOS
# 3        4    4 - 5 ANOS
# 2        5    5 - 6 ANOS
# 1        6    6 - 7 ANOS
# 7        7     ATÉ 1 ANO

# %%
#adiciona a variável Safra de Reclamação codificada ao dataframe
le_safra_reclamacao = preprocessing.LabelEncoder()
encode_safra_reclamacao = le_safra_reclamacao.fit(estoque['Safra de Reclamação'].astype(str))
explicativas['safra_reclamacao'] = encode_safra_reclamacao.transform(dados_condenacao_geral['Safra de Reclamação'].astype(str))
dados_condenacao_geral['safra_reclamacao'] = encode_safra_reclamacao.transform(dados_condenacao_geral['Safra de Reclamação'].astype(str))
explicativas_cargo['safra_reclamacao'] = encode_safra_reclamacao.transform(dados_condenacao_cargo['Safra de Reclamação'].astype(str))
explicativas_estoque['safra_reclamacao'] = encode_safra_reclamacao.transform(estoque_cargo['Safra de Reclamação'].astype(str))

#gera o de-para dos cluster pedidos
safra_reclamacao = pd.DataFrame()
safra_reclamacao['codigos'] = explicativas_estoque['safra_reclamacao'].unique()
safra_reclamacao['safra_reclamacao'] = encode_safra_reclamacao.inverse_transform(safra_reclamacao.codigos)
safra_reclamacao.sort_values(by='codigos')
# Out:
#     codigos safra_reclamacao
# 25        0             1900
# 22        6             1995
# 17        8             1997
# 2        10             1999
# 23       11             2000
# 20       13             2002
# 1        14             2003
# 18       15             2004
# 19       16             2005
# 7        17             2006
# 11       18             2007
# 5        19             2008
# 0        20             2009
# 8        21             2010
# 6        22             2011
# 4        23             2012
# 3        24             2013
# 9        25             2014
# 10       26             2015
# 13       27             2016
# 12       28             2017
# 16       29             2018
# 15       30             2019
# 21       31             2020
# 24       32             2021
# 14       34         Sem info

# %%
le_ET = preprocessing.LabelEncoder()
encode_ET = le_ET.fit(estoque['ET'])
explicativas['ET'] = encode_ET.transform(dados_condenacao_geral['ET'])
explicativas_cargo['ET'] = encode_ET.transform(dados_condenacao_cargo['ET'])
explicativas_estoque['ET'] = encode_ET.transform(estoque_cargo['ET'])

#gera o de-para dos cluster aging
ET = pd.DataFrame()
ET['codigos'] = explicativas_estoque['ET'].unique()
ET['ET'] = encode_ET.inverse_transform(ET.codigos)
ET.sort_values(by='codigos')
# Out:
#    codigos                   ET
# 3        0             Comércio
# 4        1  Cosultoria/Negócios
# 6        2             Montagem
# 1        3               Outros
# 0        4            Segurança
# 5        5             Sem info
# 2        6           Transporte

# %%
    
#substitui nulos nas variáveis qualitativas por -999
#Como estamos trabalhando com modelos de árvore, os valores sem dados serão tratados como uma categoria à parte, muito distante das demais
explicativas = explicativas.fillna(-999)
explicativas_cargo = explicativas_cargo.fillna(-999)
explicativas_estoque = explicativas_estoque.fillna(-999)


#prepara target
resposta_cargo = pd.DataFrame(dados_condenacao_cargo['Pagamento Desindexado'])

# %% [markdown]
# ## Treinamento das Árvores de Decisão
#
# Optamos por utilizar Árvores de Decisão pelos seguintes motivos:
#
# 1) Capacidade de Capturar Relações não lineares entre as variáveis explicativas e a resposta, uma vez que a correlação calculada das variáveis disponíveis na base de dados eram muito baixas. Além disso, os teste de ANOVA endossam que as variáveis, apesar da baixa correlação, quando devidamente clusterizadas apontam para uma boa capacidade de separação entre valores mais altos e mais baixos de Pagamentos
#
# 2) Simplicidade de apresentação e explicação do modelo e de suas variáveis, uma vez que obtemos uma saída visual
#
# 3) Velocidade de treinamento (permitindo inúmeras simulações e testes)

# %%
cargo
# Out:
#     codigos             cargo
# 0         3          AUXILIAR
# 1         0          AJUDANTE
# 2         2          ANALISTA
# 3         9            OUTROS
# 4        10          VENDEDOR
# 5         6          MONTADOR
# 6         7         MOTORISTA
# 7         1  AJUDANTE EXTERNO
# 8         8          OPERADOR
# 9         5           GERENTE
# 10        4             CAIXA

# %%
#Construção do Modelo de Árvore de Decisão para Regressão - resposta numérica contínua
#Em cenários de classificação podemos usar a DecisionTreeClassifier
#É possível customizar critérios de parada através dos hiperparâmetros do modelo
DT = tree.DecisionTreeRegressor(random_state=42, 
                                max_depth=100, 
                                criterion='mae',
                                min_samples_leaf = 50)


#prepara target
resposta = pd.DataFrame(dados_condenacao_cargo['Pagamento Desindexado'])

DT = DT.fit(explicativas_cargo[['cluster_valor', 'Cluster Aging', 'ET','cargo_tratado']], resposta_cargo['Pagamento Desindexado'])

# %%
#Gera o gráfico da árvore de decisão e plota na tela
graph_data = tree.export_graphviz(DT, out_file=None, 
                                  feature_names=explicativas_cargo[['cluster_valor', 'Cluster Aging', 'ET','cargo_tratado']].columns,
                                  filled=True, rounded=True,  
                                  special_characters=True)  
graph = graphviz.Source(graph_data)  
graph

# %%
#Salva a árvore de devisão. O formato padrão do graphviz é o dot - vetorial -, então precisamos executar uma função que converte o formato para .png
graph.save('decision_tree_desindexado_INSOLVENTE.dot')
# !dot -Tpng decision_tree_desindexado_INSOLVENTE.dot -o decision_tree_desindexado_INSOLVENTE.png

# %%
y_true = resposta_cargo['Pagamento Desindexado']
#y_pred = valor previsto pelo modelo treinado
y_pred = DT.predict(explicativas_cargo[['cluster_valor', 'Cluster Aging', 'ET','cargo_tratado']])

# %%
#Calcula o R-quadrado
r2_score(y_true, y_pred)
# Out:
# 0.059977293453017055

# %%
#Calcula o MAPE
mean_absolute_percentage_error(y_true, y_pred)
# Out:
# 1.731164009046472

# %%
#Calcula o MAE
mean_absolute_error(y_true, y_pred)
# Out:
# 34550.198315246475

# %%
dados_estoque_full = estoque_cargo
#dados_estoque_full = dados_estoque
dados_estoque_full['prediction'] = DT.predict(explicativas_estoque[['cluster_valor', 'Cluster Aging', 'ET','cargo_tratado']])
#dados_estoque_full['prediction'] = DT.predict(explicativas_estoque[['cluster_valor', 'Cluster Aging Tempo de Empresa', 'Cluster Aging','safra_reclamacao']][explicativas.cargo_tratado == 10])
# Out:
# <ipython-input-57-0669e83ae87a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_estoque_full['prediction'] = DT.predict(explicativas_estoque[['cluster_valor', 'Cluster Aging', 'ET','cargo_tratado']])

# %%
dados_estoque_full.to_excel('Estoque_INSOLVENTE_NOVPREV.xls', index = False)
#dados_estoque.to_excel('previsao_condenacao_outros.xls')
# Out:
# <ipython-input-58-3355633b6e6c>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   dados_estoque_full.to_excel('Estoque_INSOLVENTE_NOVPREV.xls', index = False)
